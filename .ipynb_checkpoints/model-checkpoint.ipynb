# %%
# Step 1: Import libraries
import os
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Step 2: Define dataset paths
TRAIN_DIR = r"C:\Users\rethi\Downloads\glaudata\train"
TEST_DIR  = r"C:\Users\rethi\Downloads\glaudata\test"

# Parameters
IMG_SIZE = 224   # smaller than 256 for efficiency
BATCH_SIZE = 32
EPOCHS = 20

# %%
# Step 3: Data Generators (with rescale and augmentation)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True,
    validation_split=0.2   # 80% train, 20% validation
)

# Train data
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training"
)

# Validation data
val_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation"
)

# Test data (only rescale, no augmentation)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 908 images belonging to 2 classes.
# Found 226 images belonging to 2 classes.
# Found 322 images belonging to 2 classes.

# %%
# Step 4: Define CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    MaxPooling2D(2,2),
    Dropout(0.25),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.25),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')   # 2 classes
])

# Compile
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# C:\python\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# Step 5: Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    verbose=1
)
# Out:
# C:\python\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.5320 - loss: 3.5916 - val_accuracy: 0.5885 - val_loss: 0.6815
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.7983 - loss: 0.4258 - val_accuracy: 0.5841 - val_loss: 0.6823
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.7922 - loss: 0.4550 - val_accuracy: 0.5752 - val_loss: 0.8293
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.8139 - loss: 0.4194 - val_accuracy: 0.5929 - val_loss: 0.7428
# Epoch 5/20
# ...

# %%
# Step 6: Evaluate
test_loss, test_acc = model.evaluate(test_generator, verbose=1)
print(f"✅ Test Accuracy: {test_acc:.4f}")
print(f"✅ Test Loss: {test_loss:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 805ms/step - accuracy: 0.6892 - loss: 0.6128
# ✅ Test Accuracy: 0.8199
# ✅ Test Loss: 0.4262

# %%
# Step 7: Plot accuracy & loss
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

print(classification_report(test_generator.classes, y_pred, target_names=["Normal", "Glaucoma"]))

cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Normal", "Glaucoma"], yticklabels=["Normal", "Glaucoma"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 734ms/step
#               precision    recall  f1-score   support
#
#       Normal       0.86      0.74      0.79       151
#     Glaucoma       0.79      0.89      0.84       171
#
#     accuracy                           0.82       322
#    macro avg       0.83      0.81      0.82       322
# weighted avg       0.82      0.82      0.82       322

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,
    class_weight=class_weights
)
# Out:
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.9114 - loss: 0.2400 - val_accuracy: 0.4823 - val_loss: 0.7953
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.8924 - loss: 0.2628 - val_accuracy: 0.5133 - val_loss: 0.7957
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9157 - loss: 0.2309 - val_accuracy: 0.5133 - val_loss: 0.8373
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.8931 - loss: 0.2522 - val_accuracy: 0.5221 - val_loss: 0.8577
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.8944 - loss: 0.2593 - val_accuracy: 0.5708 - val_loss: 0.9107
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9345 - loss: 0.1997 - val_accuracy: 0.5619 - val_loss: 0.7678
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9178 - loss: 0.2374 - val_accuracy: 0.5619 - val_loss: 1.0972
# Epoch 8/20
# ...

# %%
import numpy as np
import cv2

def preprocess_image(image_path, IMG_SIZE=224):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img_normalized = img_resized / 255.0
    img_input = np.expand_dims(img_normalized, axis=0)  # add batch dimension
    return img_input

# Preprocess
img_input = preprocess_image(r"C:\Users\rethi\Downloads\glaudata\test\normal\492.jpg")

# Predict
probs = model.predict(img_input)[0]

# Apply custom threshold
if probs[1] > 0.75:  
    pred = "Glaucoma"
else:
    pred = "Normal"


print(f"Prediction: {pred}, Probabilities: {probs}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Prediction: Normal, Probabilities: [0.35255298 0.6474471 ]

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Get predictions on test set
y_pred_proba = model.predict(test_generator, verbose=1)[:,1]  # probability of class 1 (Glaucoma)
y_true = test_generator.classes  # ground truth labels

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
roc_auc = auc(fpr, tpr)

# Find best threshold (Youden’s J statistic = sensitivity + specificity - 1)
best_idx = np.argmax(tpr - fpr)
best_threshold = thresholds[best_idx]

print("Best Threshold:", best_threshold)

# Plot ROC curve
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color='b', label=f"AUC = {roc_auc:.2f}")
plt.scatter(fpr[best_idx], tpr[best_idx], color='red', label=f"Best threshold = {best_threshold:.2f}")
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 924ms/step
# Best Threshold: 0.5157658

# %%
import numpy as np
import cv2

def preprocess_image(image_path, IMG_SIZE=224):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img_normalized = img_resized / 255.0
    img_input = np.expand_dims(img_normalized, axis=0)  # add batch dimension
    return img_input

# Preprocess
img_input = preprocess_image(r"C:\Users\rethi\Downloads\glaudata\test\glaucoma\608.jpg")

# Predict
probs = model.predict(img_input)[0]

# Apply custom threshold
if probs[1] > best_threshold:
    pred = "Glaucoma"
else:
    pred = "Normal"


print(f"Prediction: {pred}, Probabilities: {probs}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Prediction: Normal, Probabilities: [0.49696583 0.50303423]

# %%
print("Best threshold used:", best_threshold)
# Out:
# Best threshold used: 0.5157658

# %%
custom_threshold = 0.50
pred = "Glaucoma" if probs[1] > custom_threshold else "Normal"

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

print(classification_report(test_generator.classes, y_pred, target_names=["Normal", "Glaucoma"]))

cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Normal", "Glaucoma"], yticklabels=["Normal", "Glaucoma"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 773ms/step
#               precision    recall  f1-score   support
#
#       Normal       0.85      0.72      0.78       151
#     Glaucoma       0.78      0.89      0.83       171
#
#     accuracy                           0.81       322
#    macro avg       0.81      0.80      0.80       322
# weighted avg       0.81      0.81      0.81       322

# %%
import os

test_dir = r"C:\Users\rethi\Downloads\glaudata\test\normal"
for img_name in os.listdir(test_dir)[:10]:  # check first 10
    img_path = os.path.join(test_dir, img_name)
    img_input = preprocess_image(img_path)
    probs = model.predict(img_input)[0]
    pred = "Glaucoma" if probs[1] > 0.55 else "Normal"
    print(f"{img_name} → Predicted: {pred}, Probs: {probs}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 466.jpg → Predicted: Glaucoma, Probs: [0.38249186 0.6175081 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 467.jpg → Predicted: Glaucoma, Probs: [0.09601893 0.9039811 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 469.jpg → Predicted: Glaucoma, Probs: [0.23736297 0.7626371 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 470.jpg → Predicted: Glaucoma, Probs: [0.24744442 0.7525556 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 488.jpg → Predicted: Glaucoma, Probs: [0.08661928 0.9133807 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 489.jpg → Predicted: Glaucoma, Probs: [0.05039606 0.9496039 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 491.jpg → Predicted: Glaucoma, Probs: [0.33154103 0.668459  ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 492.jpg → Predicted: Glaucoma, Probs: [0.35255298 0.6474471 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 493.jpg → Predicted: Glaucoma, Probs: [0.35963598 0.64036405]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ...

# %%
print("Train:", train_generator.class_indices)
print("Samples per class:", train_generator.classes.shape)
unique, counts = np.unique(train_generator.classes, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# Train: {'glaucoma': 0, 'normal': 1}
# Samples per class: (908,)
# {np.int32(0): np.int64(387), np.int32(1): np.int64(521)}

# %%
from sklearn.utils import class_weight
import numpy as np

class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,
    class_weight=class_weights
)
# Out:
# Class Weights: {0: np.float64(1.17312661498708), 1: np.float64(0.8714011516314779)}
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9284 - loss: 0.2037 - val_accuracy: 0.5575 - val_loss: 1.0390
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9063 - loss: 0.2215 - val_accuracy: 0.5310 - val_loss: 0.9502
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9261 - loss: 0.2074 - val_accuracy: 0.5531 - val_loss: 0.8198
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9115 - loss: 0.2292 - val_accuracy: 0.5708 - val_loss: 1.1431
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9075 - loss: 0.2557 - val_accuracy: 0.5708 - val_loss: 1.2558
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.9201 - loss: 0.2226 - val_accuracy: 0.5664 - val_loss: 0.9141
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.9158 - loss: 0.2031 - val_accuracy: 0.5310 - val_loss: 0.8305
# ...

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    zoom_range=0.3,
    shear_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=30,
    class_weight=class_weights
)
# Out:
# Epoch 1/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9437 - loss: 0.1463 - val_accuracy: 0.5442 - val_loss: 1.0660
# Epoch 2/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.9313 - loss: 0.1639 - val_accuracy: 0.5221 - val_loss: 1.0549
# Epoch 3/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9242 - loss: 0.1843 - val_accuracy: 0.5796 - val_loss: 1.8786
# Epoch 4/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.8923 - loss: 0.3267 - val_accuracy: 0.6018 - val_loss: 1.0319
# Epoch 5/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9007 - loss: 0.2589 - val_accuracy: 0.5619 - val_loss: 1.1492
# Epoch 6/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9214 - loss: 0.2152 - val_accuracy: 0.5531 - val_loss: 0.8783
# Epoch 7/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9205 - loss: 0.1869 - val_accuracy: 0.5664 - val_loss: 1.2054
# Epoch 8/30
# ...

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

print(classification_report(test_generator.classes, y_pred, target_names=["Normal", "Glaucoma"]))

cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Normal", "Glaucoma"], yticklabels=["Normal", "Glaucoma"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step
#               precision    recall  f1-score   support
#
#       Normal       0.84      0.72      0.78       151
#     Glaucoma       0.78      0.88      0.83       171
#
#     accuracy                           0.80       322
#    macro avg       0.81      0.80      0.80       322
# weighted avg       0.81      0.80      0.80       322

# %%
import numpy as np
import cv2

def preprocess_image(image_path, IMG_SIZE=224):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img_normalized = img_resized / 255.0
    img_input = np.expand_dims(img_normalized, axis=0)  # add batch dimension
    return img_input

# Preprocess
img_input = preprocess_image(r"C:\Users\rethi\Downloads\glaudata\test\normal\492.jpg")

# Predict
probs = model.predict(img_input)[0]

# Apply custom threshold
if probs[1] > 0.75:  
    pred = "Glaucoma"
else:
    pred = "Normal"


print(f"Prediction: {pred}, Probabilities: {probs}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Prediction: Normal, Probabilities: [0.41327083 0.58672917]

# %%
import numpy as np
import cv2

def preprocess_image(image_path, IMG_SIZE=224):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img_normalized = img_resized / 255.0
    img_input = np.expand_dims(img_normalized, axis=0)  # add batch dimension
    return img_input

# Preprocess
img_input = preprocess_image(r"C:\Users\rethi\Downloads\glaudata\test\glaucoma\608.jpg")

# Predict
probs = model.predict(img_input)[0]

# Apply custom threshold
if probs[1] > best_threshold:
    pred = "Glaucoma"
else:
    pred = "Normal"


print(f"Prediction: {pred}, Probabilities: {probs}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Prediction: Glaucoma, Probabilities: [0.37093464 0.62906533]
