# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
import shutil
import random
from tqdm import tqdm
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, MaxPooling2D

# %%
# Step 2: Define dataset paths
train_dir = r"C:\Users\rethi\Downloads\glaudata\train"
test_dir = r"C:\Users\rethi\Downloads\glaudata\test"

# %%
import os
import cv2
import numpy as np
import random
from tqdm import tqdm
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomContrast, RandomTranslation
from tensorflow.keras.models import Sequential
from sklearn.utils import shuffle

# Set seed for reproducibility
random.seed(1)
np.random.seed(1)

# Define dataset path and categories
DATADIR = r"C:\Users\rethi\Downloads\glaudata\train"
CATEGORIES = ["normal", "glaucoma"]

IMG_SIZE = 256
training_data = []

# Function to create training dataset
def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)

        for img in tqdm(os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)  # Read image
                if img_array is None:
                    continue  # Skip if image is not read
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # Resize image
                training_data.append([new_array, class_num])
            except Exception as e:
                print(f"Error loading {img}: {e}")

# Run dataset creation
create_training_data()

# Shuffle the dataset
training_data = shuffle(training_data, random_state=1)

# Data Augmentation Pipeline
data_augmentation = Sequential([
    RandomFlip(mode="horizontal_and_vertical", seed=1),
    RandomRotation(factor=0.1, seed=1),  # ±10 degrees
    RandomContrast(factor=0.1, seed=1),
    RandomTranslation(height_factor=0.15, width_factor=0.15, fill_mode='wrap', seed=1)
])
'''
# Function for Histogram Equalization
def he(img):
    ycrcb = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)  # Convert to YCrCb
    y, cr, cb = cv2.split(ycrcb)  # Split channels
    y_eq = cv2.equalizeHist(y)  # Apply histogram equalization on Y channel
    merged = cv2.merge((y_eq, cr, cb))  # Merge channels back
    return cv2.cvtColor(merged, cv2.COLOR_YCrCb2BGR)  # Convert back to BGR
'''
# Function for CLAHE (Contrast Limited Adaptive Histogram Equalization)
def clahe(img):
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)  # Convert to LAB
    l, a, b = cv2.split(lab)  # Split channels
    clahe = cv2.createCLAHE(clipLimit=3.5, tileGridSize=(8, 8))  # Define CLAHE
    l_clahe = clahe.apply(l)  # Apply CLAHE to L channel
    merged = cv2.merge((l_clahe, a, b))  # Merge LAB channels back
    return cv2.cvtColor(merged, cv2.COLOR_LAB2BGR)  # Convert back to BGR

# Apply Preprocessing
X = []
y = []

for features, label in training_data:
    features = clahe(features)  # Apply CLAHE
    X.append(features)
    y.append(label)

# Convert to NumPy arrays
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
y = np.array(y)

print(f"Dataset loaded: {X.shape}, Labels: {y.shape}")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 651/651 [00:14<00:00, 45.21it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 484/484 [00:07<00:00, 62.31it/s]
# Dataset loaded: (1134, 256, 256, 3), Labels: (1134,)

# %%
import matplotlib.pyplot as plt

# Number of images to display
num_images = 5  

plt.figure(figsize=(12, 12))

for i in range(num_images):
    original_img = training_data[i][0]  # Get original image before preprocessing
    preprocessed_img = X[i]  # Get preprocessed image
    
    # Convert BGR to RGB for proper display
    original_img_rgb = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
    preprocessed_img_rgb = cv2.cvtColor(preprocessed_img, cv2.COLOR_BGR2RGB)

    # Display original image
    plt.subplot(num_images, 2, 2 * i + 1)
    plt.imshow(original_img_rgb)
    plt.axis("off")
    plt.title(f"Original - Label: {y[i]}")

    # Display preprocessed image
    plt.subplot(num_images, 2, 2 * i + 2)
    plt.imshow(preprocessed_img_rgb)
    plt.axis("off")
    plt.title(f"Preprocessed - Label: {y[i]}")

plt.tight_layout()
plt.show()

# %%
# plotting training dataset
plt.figure(figsize=(14,6))
colors = ['#4285f4', '#ea4335']
plt.rcParams.update({'font.size': 14})
plt.pie([list(y).count(0), list(y).count(1)],
        labels=CATEGORIES,
        colors=colors, autopct='%.1f%%', explode=(0.025,0.025),
        startangle=90);

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import RandomRotation, RandomTranslation

IMG_SIZE = 256
NUM_CLASSES = 2  # Two categories: 'normal' and 'glaucoma'

# Load ResNet50 as base model (pre-trained on ImageNet)
base_model = ResNet50(input_shape=(IMG_SIZE, IMG_SIZE, 3), include_top=False, weights='imagenet')

# Freeze all layers initially
base_model.trainable = False

# Unfreeze last few layers for fine-tuning
for layer in base_model.layers[-10:]:  # Fine-tune last 10 layers
    layer.trainable = True

# Define the model
model = Sequential([
    # Data augmentation layers (only applied during training) - Removed RandomFlip
    RandomRotation(0.1),  # ±10 degrees
    RandomTranslation(height_factor=0.15, width_factor=0.15, fill_mode='wrap'),

    # Pre-trained ResNet50 as feature extractor
    base_model,

    # Feature extraction layer
    GlobalAveragePooling2D(),

    # Fully connected layers
    Dropout(0.5),  # Dropout before Dense to reduce overfitting
    Dense(256, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')  # Output layer
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4),  # Learning rate written in scientific notation
              loss='sparse_categorical_crossentropy',  # Use if labels are integers (0,1)
              metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_rotation_1 (RandomRotation)   │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation_1                 │ ?                           │     0 (unbuilt) │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 8, 8, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ ?                           │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 4,465,664 (17.04 MB)
#  Non-trainable params: 19,122,048 (72.94 MB)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# training the model
batch_size = 32
epochs = 40
early_stop = EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)
history = model.fit(X, y, batch_size=batch_size, epochs=50, validation_split=0.15)  # Stop early if no improvement

'''
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=40,  # Start with a high number
    callbacks=[early_stop]  # Stop early if no improvement
)
'''
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.6220 - loss: 0.8703 - val_accuracy: 0.6667 - val_loss: 0.8710
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 134s 4s/step - accuracy: 0.7724 - loss: 0.5265 - val_accuracy: 0.6725 - val_loss: 0.7392
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.7803 - loss: 0.4808 - val_accuracy: 0.7778 - val_loss: 0.4542
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.8598 - loss: 0.3455 - val_accuracy: 0.8363 - val_loss: 0.3910
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 129s 4s/step - accuracy: 0.8559 - loss: 0.3362 - val_accuracy: 0.8713 - val_loss: 0.3599
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 127s 4s/step - accuracy: 0.8417 - loss: 0.3614 - val_accuracy: 0.8070 - val_loss: 0.5843
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.8518 - loss: 0.3297 - val_accuracy: 0.7719 - val_loss: 0.6512
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.8940 - loss: 0.2670 - val_accuracy: 0.8129 - val_loss: 0.3467
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.8789 - loss: 0.3035 - val_accuracy: 0.8187 - val_loss: 0.3238
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step - accuracy: 0.8873 - loss: 0.2803 - val_accuracy: 0.7778 - val_loss: 0.6872
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.8978 - loss: 0.2446 - val_accuracy: 0.8480 - val_loss: 0.3433
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 102s 3s/step - accuracy: 0.8987 - loss: 0.2737 - val_accuracy: 0.8889 - val_loss: 0.2467
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.8870 - loss: 0.2415 - val_accuracy: 0.7544 - val_loss: 0.7329
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.9028 - loss: 0.2063 - val_accuracy: 0.8363 - val_loss: 0.4378
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 102s 3s/step - accuracy: 0.9069 - loss: 0.2147 - val_accuracy: 0.8538 - val_loss: 0.2679
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.9314 - loss: 0.1791 - val_accuracy: 0.8596 - val_loss: 0.2835
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 102s 3s/step - accuracy: 0.9276 - loss: 0.1846 - val_accuracy: 0.8421 - val_loss: 0.4477
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.9119 - loss: 0.2068 - val_accuracy: 0.7836 - val_loss: 0.8136
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 102s 3s/step - accuracy: 0.9495 - loss: 0.1304 - val_accuracy: 0.8538 - val_loss: 0.4210
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.9275 - loss: 0.1956 - val_accuracy: 0.8655 - val_loss: 0.3076
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.
predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Raw prediction: [[0.42488328 0.5751167 ]]
# Predicted class: 1
# Label: glaucoma

# %%
# STEP 1: Function to preprocess image (you already have this)
def preprocess_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img = clahe(img)  # Apply CLAHE (same as training)
    img = np.array(img).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
    return img

# %%
# STEP 2: Function to predict
def predict_image(img_path, model):
    img = preprocess_image(img_path)        # preprocess the given image
    pred = model.predict(img)               # model makes prediction
    predicted_class = np.argmax(pred, axis=1)[0]  # take highest probability
    print("Raw prediction:", pred)
    print("Predicted class:", predicted_class, "->", CATEGORIES[predicted_class])

# %%
# Example: test with one image
predict_image(r"C:\Users\rethi\Downloads\glaudata\test\normal\488.jpg", model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Raw prediction: [[9.997385e-01 2.615038e-04]]
# Predicted class: 0 -> normal

# %%
predict_image(r"C:\Users\rethi\Downloads\glaudata\test\glaucoma\612.jpg", model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# Raw prediction: [[0.7023211  0.29767895]]
# Predicted class: 0 -> normal

# %%
import os

normal_count = len(os.listdir(r"C:\Users\rethi\Downloads\glaudata\train\normal"))
glaucoma_count = len(os.listdir(r"C:\Users\rethi\Downloads\glaudata\train\glaucoma"))
print("normal:", normal_count, " glaucoma:", glaucoma_count)
# Out:
# normal: 651  glaucoma: 484

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 224
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    r"C:\Users\rethi\Downloads\glaudata\train",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 908 images belonging to 2 classes.

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# classes are [0, 1] -> normal, glaucoma
classes = np.array([0, 1])

# y contains all the labels from train_generator
y = train_generator.classes  

# compute balanced class weights
class_weights = compute_class_weight(class_weight="balanced", classes=classes, y=y)
class_weights = dict(enumerate(class_weights))

print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: np.float64(1.17312661498708), 1: np.float64(0.8714011516314779)}

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 256
BATCH_SIZE = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.15  # 15% for validation
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="sparse",
    subset="training",
    shuffle=True
)

val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="sparse",
    subset="validation",
    shuffle=True
)
# Out:
# Found 965 images belonging to 2 classes.
# Found 169 images belonging to 2 classes.

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=40,
    class_weight=class_weights
)
# Out:
# C:\python\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 143s 4s/step - accuracy: 0.4960 - loss: 0.9713 - val_accuracy: 0.5740 - val_loss: 3.5005
# Epoch 2/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 121s 4s/step - accuracy: 0.6256 - loss: 0.6792 - val_accuracy: 0.5740 - val_loss: 2.3959
# Epoch 3/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.6565 - loss: 0.6417 - val_accuracy: 0.5740 - val_loss: 1.4384
# Epoch 4/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.6607 - loss: 0.6642 - val_accuracy: 0.5740 - val_loss: 1.2852
# Epoch 5/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 122s 4s/step - accuracy: 0.6921 - loss: 0.5756 - val_accuracy: 0.5740 - val_loss: 1.1990
# Epoch 6/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 131s 4s/step - accuracy: 0.7213 - loss: 0.5412 - val_accuracy: 0.5740 - val_loss: 0.8125
# Epoch 7/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.7311 - loss: 0.5546 - val_accuracy: 0.5740 - val_loss: 1.1418
# Epoch 8/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.6664 - loss: 0.5979 - val_accuracy: 0.6627 - val_loss: 0.7763
# Epoch 9/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.7036 - loss: 0.5550 - val_accuracy: 0.5740 - val_loss: 1.3906
# Epoch 10/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.7400 - loss: 0.5245 - val_accuracy: 0.5740 - val_loss: 1.7128
# Epoch 11/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.7533 - loss: 0.5058 - val_accuracy: 0.4260 - val_loss: 3.2294
# Epoch 12/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.7239 - loss: 0.5323 - val_accuracy: 0.4260 - val_loss: 5.1571
# Epoch 13/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.7676 - loss: 0.5188 - val_accuracy: 0.5030 - val_loss: 0.7846
# Epoch 14/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.7681 - loss: 0.4949 - val_accuracy: 0.4142 - val_loss: 2.4314
# Epoch 15/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.7630 - loss: 0.4940 - val_accuracy: 0.4320 - val_loss: 0.8689
# Epoch 16/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.7842 - loss: 0.4965 - val_accuracy: 0.5740 - val_loss: 2.2092
# Epoch 17/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.7950 - loss: 0.4819 - val_accuracy: 0.4083 - val_loss: 1.6082
# Epoch 18/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.7842 - loss: 0.4960 - val_accuracy: 0.4260 - val_loss: 4.7321
# Epoch 19/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.7736 - loss: 0.4714 - val_accuracy: 0.4142 - val_loss: 1.2922
# Epoch 20/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.7853 - loss: 0.4598 - val_accuracy: 0.4260 - val_loss: 9.5896
# Epoch 21/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1193s 40s/step - accuracy: 0.8001 - loss: 0.4424 - val_accuracy: 0.4260 - val_loss: 2.5731
# Epoch 22/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 102s 3s/step - accuracy: 0.7141 - loss: 0.5351 - val_accuracy: 0.4260 - val_loss: 6.7064
# Epoch 23/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.7741 - loss: 0.4693 - val_accuracy: 0.6036 - val_loss: 0.7308
# Epoch 24/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 102s 3s/step - accuracy: 0.7803 - loss: 0.4742 - val_accuracy: 0.4142 - val_loss: 1.4298
# Epoch 25/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.7974 - loss: 0.4497 - val_accuracy: 0.4201 - val_loss: 1.5932
# Epoch 26/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 102s 3s/step - accuracy: 0.7994 - loss: 0.4366 - val_accuracy: 0.4260 - val_loss: 4.6753
# Epoch 27/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.7803 - loss: 0.4635 - val_accuracy: 0.5858 - val_loss: 0.8499
# Epoch 28/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.7747 - loss: 0.4797 - val_accuracy: 0.5858 - val_loss: 0.7108
# Epoch 29/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.7979 - loss: 0.4880 - val_accuracy: 0.5740 - val_loss: 0.8179
# Epoch 30/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.8377 - loss: 0.4271 - val_accuracy: 0.5740 - val_loss: 1.8917
# Epoch 31/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.8135 - loss: 0.4619 - val_accuracy: 0.4024 - val_loss: 1.1189
# Epoch 32/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.8112 - loss: 0.4715 - val_accuracy: 0.5740 - val_loss: 3.0244
# Epoch 33/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.8282 - loss: 0.4372 - val_accuracy: 0.5740 - val_loss: 1.5570
# Epoch 34/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.8136 - loss: 0.4213 - val_accuracy: 0.4260 - val_loss: 5.1444
# Epoch 35/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 102s 3s/step - accuracy: 0.8256 - loss: 0.4017 - val_accuracy: 0.4142 - val_loss: 2.1075
# Epoch 36/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.8020 - loss: 0.4245 - val_accuracy: 0.4260 - val_loss: 21.7308
# Epoch 37/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.7909 - loss: 0.4861 - val_accuracy: 0.5740 - val_loss: 4.3070
# Epoch 38/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.8027 - loss: 0.4462 - val_accuracy: 0.4260 - val_loss: 11.9255
# Epoch 39/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.8290 - loss: 0.3781 - val_accuracy: 0.5740 - val_loss: 2.0776
# Epoch 40/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.7840 - loss: 0.4214 - val_accuracy: 0.4260 - val_loss: 27.6818

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Conv2D

# Example usage
Conv2D(32, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001))
# Out:
# <Conv2D name=conv2d, built=False>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import regularizers

model = Sequential([
    Conv2D(32, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(224,224,3)),
    MaxPooling2D((2,2)),
    Dropout(0.3),

    Conv2D(64, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    MaxPooling2D((2,2)),
    Dropout(0.3),

    Conv2D(128, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    MaxPooling2D((2,2)),
    Dropout(0.4),

    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),

    Dense(2, activation='softmax')  # 2 classes: normal & glaucoma
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# C:\python\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)                    │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 52, 52, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 86528)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │      11,075,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,169,218 (42.61 MB)
#  Trainable params: 11,169,218 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
Conv2D(32, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(256,256,3))
# Out:
# <Conv2D name=conv2d_4, built=False>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import regularizers

IMG_SIZE = 224  # make sure matches generator

model = Sequential([
    Conv2D(32, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')   # 2 classes: normal vs glaucoma
])
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)                    │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 52, 52, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 86528)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │      11,075,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,169,218 (42.61 MB)
#  Trainable params: 11,169,218 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 224  # must match model input

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.15)

train_generator = train_datagen.flow_from_directory(
    r"C:\Users\rethi\Downloads\glaudata\train",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    r"C:\Users\rethi\Downloads\glaudata\train",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found
40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9408 - loss: 0.1715 - val_accuracy: 0.5858 - val_loss: 0.8762
# Epoch 33/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9062 - loss: 0.2025 - val_accuracy: 0.5976 - val_loss: 0.9904
# Epoch 34/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9298 - loss: 0.1745 - val_accuracy: 0.5858 - val_loss: 1.4051
# Epoch 35/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9156 - loss: 0.1971 - val_accuracy: 0.5858 - val_loss: 0.9816
# Epoch 36/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9092 - loss: 0.2074 - val_accuracy: 0.5917 - val_loss: 1.1894
# Epoch 37/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9362 - loss: 0.1823 - val_accuracy: 0.5858 - val_loss: 1.0593
# Epoch 38/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9177 - loss: 0.1762 - val_accuracy: 0.5562 - val_loss: 0.8132
# Epoch 39/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9097 - loss: 0.2704 - val_accuracy: 0.5858 - val_loss: 0.8812
# Epoch 40/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9332 - loss: 0.1949 - val_accuracy: 0.5740 - val_loss: 0.9272

# %%
# STEP 2: Function to predict
def predict_image(img_path, model):
    img = preprocess_image(img_path)        # preprocess the given image
    pred = model.predict(img)               # model makes prediction
    predicted_class = np.argmax(pred, axis=1)[0]  # take highest probability
    print("Raw prediction:", pred)
    print("Predicted class:", predicted_class, "->", CATEGORIES[predicted_class])

# %%
predict_image(r"C:\Users\rethi\Downloads\glaudata\test\normal\469.jpg", model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Raw prediction: [[0. 1.]]
# Predicted class: 1 -> glaucoma

# %%
model.save("model.h5")
print("Model saved successfully.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully.

# %%
# Define test dataset path
TEST_DIR = r"C:\Users\rethi\Downloads\glaudata\test"

test_data = []
IMG_SIZE = 224
CATEGORIES = ["normal", "glaucoma"]

# Load and preprocess test data
for category in CATEGORIES:
    path = os.path.join(TEST_DIR, category)
    class_num = CATEGORIES.index(category)

    for img in os.listdir(path):
        try:
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
            if img_array is None:
                continue
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # Resize image
            img_preprocessed = clahe(img_resized)  # Apply same preprocessing as training data
            test_data.append([img_preprocessed, class_num])
        except Exception as e:
            print(f"Error loading {img}: {e}")

# Shuffle and convert test data to arrays
test_data = shuffle(test_data, random_state=1)
X_test = np.array([i[0] for i in test_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
y_test = np.array([i[1] for i in test_data])

# %%
from tensorflow.keras.models import load_model
model = load_model("model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Normalize (if you didn't already do rescale=1./255 in preprocessing)
X_test = X_test / 255.0  

# One-hot encode labels if your model uses categorical_crossentropy
from tensorflow.keras.utils import to_categorical
y_test_cat = to_categorical(y_test, num_classes=2)

test_loss, test_acc = model.evaluate(X_test, y_test_cat, verbose=1)
print(f"✅ Test Accuracy: {test_acc:.4f}")
print(f"✅ Test Loss: {test_loss:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 8
#       5 from tensorflow.keras.utils import to_categorical
#       6 y_test_cat = to_categorical(y_test, num_classes=2)
# ----> 8 test_loss, test_acc = model.evaluate(X_test, y_test_cat, verbose=1)
#       9 print(f"✅ Test Accuracy: {test_acc:.4f}")
#      10 print(f"✅ Test Loss: {test_loss:.4f}")
#
# File C:\python\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File C:\python\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:132, in TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator(iterator)
#     128 @tf.autograph.experimental.do_not_convert
#     129 def multi_step_on_iterator(iterator):
#     130     if self.steps_per_execution == 1:
#     131         return tf.experimental.Optional.from_value(
# --> 132             one_step_on_data(iterator.get_next())
#     133         )
#     135     # the spec is set lazily during the tracing of `tf.while_loop`
#     136     empty_outputs = tf.experimental.Optional.empty(None)
#
# ValueError: Creating variables on a non-first call to a function decorated with tf.function.

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class labels

print(classification_report(y_test, y_pred_classes, target_names=CATEGORIES))

# Plot confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=CATEGORIES, yticklabels=CATEGORIES)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title('Accuracy Curve')
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss Curve')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_classes, target_names=["normal", "glaucoma"]))

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_test, y_pred[:,1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f"AUC = {roc_auc:.2f}")
plt.plot([0,1],[0,1],'--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()

# %%
import numpy as np

indices = np.random.choice(len(X_test), 9, replace=False)  # pick 9 random test images
plt.figure(figsize=(10,10))

for i, idx in enumerate(indices):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[idx].astype("uint8"))
    plt.axis("off")
    plt.title(f"True: {['normal','glaucoma'][y_test[idx]]}\nPred: {['normal','glaucoma'][y_pred_classes[idx]]}")
plt.show()

# %%
model.save("data.h5")
